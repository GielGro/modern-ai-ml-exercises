# %% [markdown]
# # VisualSort — student workspace
#
# Use a GPU runtime for transfer learning: Runtime → Change runtime type → T4 GPU.

# %%
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf

DATA = Path('../data') if Path('../data').exists() else Path('data')
train_archive=np.load(DATA/'train_images.npz')
test_archive=np.load(DATA/'test_images.npz')
labels=pd.read_csv(DATA/'train_labels.csv')
label_map=pd.read_csv(DATA/'label_map.csv')
print(train_archive['images'].shape, test_archive['images'].shape)

# %% [markdown]
# ## 1. Image and class audit

# %% [markdown]
# ## 2. Flattened or shallow baseline

# %% [markdown]
# ## 3. MLP learning curves

# %% [markdown]
# ## 4. Frozen pretrained image model
# Resize to at least 32×32, replicate grayscale into three channels, and use the matching preprocessing function.

# %% [markdown]
# ## 5. Controlled fine-tuning
# Unfreeze only a small upper block and use a lower learning rate.

# %% [markdown]
# ## 6. Confusions, confidence, and review policy

# %%
# submission=pd.DataFrame({'image_id':test_archive['image_id'], 'predicted_label':predicted_labels})
# submission.to_csv('../submission.csv',index=False)

# %% [markdown]
# ## Generative AI use disclosure
# Complete the course disclosure.
