# %% [markdown]
# # Causal Campaign — student workspace
#
# Write the estimand and DAG before fitting any model.

# %%
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

DATA = Path('../data') if Path('../data').exists() else Path('data')
data=pd.read_csv(DATA/'marketing_observational.csv')
print(data.shape)
data.head()

# %% [markdown]
# ## 1. Estimand, DAG, assumptions, and adjustment set

# %% [markdown]
# ## 2. Naive estimates, overlap, and standardized mean differences

# %% [markdown]
# ## 3. Propensity model and weighting/matching

# %% [markdown]
# ## 4. Outcome regression or doubly robust estimate

# %% [markdown]
# ## 5. Uncertainty, sensitivity, and refutation

# %% [markdown]
# ## 6. Responsible targeting and next experiment

# %%
# effect_estimates.to_csv('../effect_estimates.csv',index=False)

# %% [markdown]
# ## Generative AI use disclosure
# Complete the course disclosure.
