# %% [markdown]
# # Segment Studio — student workspace
#
# There is no true label. Build evidence for a stable and useful segmentation.

# %%
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans, DBSCAN, AgglomerativeClustering
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.metrics import silhouette_score

DATA = Path('../data') if Path('../data').exists() else Path('data')
customers = pd.read_csv(DATA/'customers.csv')
print(customers.shape)
customers.head()

# %% [markdown]
# ## 1. Audit, transformations, and outliers

# %% [markdown]
# ## 2. Compare k and stability
# Do not select k from silhouette alone.

# %% [markdown]
# ## 3. Alternative algorithm and anomaly review

# %% [markdown]
# ## 4. PCA/UMAP visualization and interpretation

# %% [markdown]
# ## 5. Profiles, actions, and assignments

# %%
# segments = pd.DataFrame({'customer_id': customers.customer_id, 'segment_id': labels})
# segments.to_csv('../segments.csv', index=False)

# %% [markdown]
# ## Generative AI use disclosure
# Complete the course disclosure.
