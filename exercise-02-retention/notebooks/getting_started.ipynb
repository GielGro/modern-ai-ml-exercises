# %% [markdown]
# # Save or Let Go — student workspace
#
# Read the full problem brief before coding. Replace prompts with your own analysis; do not delete the AI-use disclosure.

# %%
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import StratifiedKFold, cross_validate
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import (log_loss, roc_auc_score, average_precision_score, confusion_matrix)

DATA = Path('../data') if Path('../data').exists() else Path('data')

# %%
train = pd.read_csv(DATA / 'train.csv')
test = pd.read_csv(DATA / 'test.csv')
costs = pd.read_csv(DATA / 'campaign_costs.csv')
print(train.shape, test.shape)
train.head()

# %% [markdown]
# ## 1. Problem framing, prevalence, and audit
#
# Define the prediction and decision problems separately.

# %% [markdown]
# ## 2. Baseline and validation design
#
# Create an always-stay baseline and a leakage-safe stratified evaluation.

# %% [markdown]
# ## 3. Logistic and regularized models
#
# Compare probability quality, ranking quality, and interpretability.

# %% [markdown]
# ## 4. Tree-based comparison
#
# Add a tree or Random Forest after Session 6.

# %% [markdown]
# ## 5. Threshold economics
#
# Plot expected campaign value by threshold and conduct sensitivity analysis.

# %% [markdown]
# ## 6. Final policy and submission

# %%
# probabilities = final_model.predict_proba(test.drop(columns='customer_id'))[:, 1]
# threshold = ...
# submission = pd.DataFrame({'customer_id': test.customer_id, 'churn_probability': probabilities, 'contact_customer': (probabilities >= threshold).astype(int)})
# submission.to_csv('../submission.csv', index=False)

# %% [markdown]
# ## Generative AI use disclosure
#
# Complete the disclosure specified in `../../shared/ai_use_disclosure.md`.
