# %% [markdown]
# # BookingGuard — student workspace
#
# Build a time-aware cancellation model and a deposit policy. Read the brief first.

# %%
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import log_loss, roc_auc_score, average_precision_score

DATA = Path('../data') if Path('../data').exists() else Path('data')
train = pd.read_csv(DATA/'train.csv')
test = pd.read_csv(DATA/'test.csv')
costs = pd.read_csv(DATA/'policy_costs.csv')
print(train.shape, test.shape)
train.head()

# %% [markdown]
# ## 1. Prediction moment and leakage audit
# Define what is knowable when the deposit decision is made.

# %% [markdown]
# ## 2. Temporal validation and baseline
# Use arrival timing to create a genuine forward validation period.

# %% [markdown]
# ## 3. Linear, bagging, and boosting comparison
# Track parameters, runtime, metrics, and calibration for every experiment.

# %% [markdown]
# ## 4. Deposit economics and sensitivity
# Convert probabilities into policy value using the published assumptions.

# %% [markdown]
# ## 5. Segment errors and final submission

# %%
# submission = pd.DataFrame({'booking_id': test.booking_id,
#   'cancellation_probability': probabilities,
#   'require_deposit': decisions})
# submission.to_csv('../submission.csv', index=False)

# %% [markdown]
# ## Generative AI use disclosure
# Complete the course disclosure.
