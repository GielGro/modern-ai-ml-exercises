# %% [markdown]
# # HomeValue — student workspace
#
# Read the full problem brief before coding. Replace prompts with your own analysis; do not delete the AI-use disclosure.

# %%
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, root_mean_squared_error

DATA = Path('../data') if Path('../data').exists() else Path('data')

# %%
train = pd.read_csv(DATA / 'train.csv')
test = pd.read_csv(DATA / 'test.csv')
print(train.shape, test.shape)
train.head()

# %% [markdown]
# ## 1. Problem framing and data audit
#
# State the unit of analysis, target, prediction moment, stakeholders, and cost of errors.

# %% [markdown]
# ## 2. Baseline and validation design
#
# Build a median baseline. Explain your split before seeing model results.

# %% [markdown]
# ## 3. Simple linear regression
#
# Select one feature, fit the model, interpret the coefficient, and inspect residuals.

# %% [markdown]
# ## 4. Multiple linear regression
#
# Build a leakage-safe preprocessing and modeling pipeline.

# %% [markdown]
# ## 5. Error analysis and business interpretation
#
# Assess errors in dollars, proportional terms, and meaningful subgroups.

# %% [markdown]
# ## 6. Final model and submission

# %%
# final_model.fit(...)
# predictions = final_model.predict(test.drop(columns='property_id'))
# submission = pd.DataFrame({'property_id': test.property_id, 'predicted_sale_price': predictions})
# submission.to_csv('../submission.csv', index=False)

# %% [markdown]
# ## Generative AI use disclosure
#
# Complete the disclosure specified in `../../shared/ai_use_disclosure.md`.
